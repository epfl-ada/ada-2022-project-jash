# %%
import pandas as pd
import numpy as np

# %%
# loading imdb actor information
actors_raw = pd.read_csv('data/name.basics.tsv/data.tsv', sep='\t')

# loading imdb's principals
principals_raw = pd.read_csv('data/title.principals.tsv/data.tsv', sep='\t')

# %%
print("Number of actors:", actors_raw.size)
actors_raw
# Out:
# Number of actors: 72892446
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12148736  nm9993714   Romeo del Rosario        \N        \N
# 12148737  nm9993716       Essias Loberg        \N        \N
# 12148738  nm9993717  Harikrishnan Rajan        \N        \N
# 12148739  nm9993718         Aayush Nair        \N        \N
# 12148740  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 12148736  animation_department,art_department
# 12148737                                  NaN
# 12148738                      cinematographer
# 12148739                      cinematographer
# 12148740                                  NaN
#
#                                    knownForTitles
# 0         tt0050419,tt0053137,tt0072308,tt0045537
# 1         tt0038355,tt0037382,tt0117057,tt0071877
# 2         tt0054452,tt0056404,tt0057345,tt0049189
# 3         tt0080455,tt0077975,tt0078723,tt0072562
# 4         tt0060827,tt0083922,tt0050976,tt0050986
# ...                                           ...
# 12148736          tt2455546,tt11657662,tt14069590
# 12148737                                       \N
# 12148738                                tt8736744
# 12148739                                       \N
# 12148740                                       \N
#
# [12148741 rows x 6 columns]

# %%
#print("Number of movies considered in 'principals' data set", len(list(dict.fromkeys(principals["tconst"]))))
principals_raw
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 53573728  tt9916880         4  nm10535738          actress
# 53573729  tt9916880         5   nm0996406         director
# 53573730  tt9916880         6   nm1482639           writer
# 53573731  tt9916880         7   nm2586970           writer
# 53573732  tt9916880         8   nm1594058         producer
#
#                               job        characters
# 0                              \N          ["Self"]
# 1                              \N                \N
# 2         director of photography                \N
# 3                              \N                \N
# 4                              \N                \N
# ...                           ...               ...
# 53573728                       \N  ["Horrid Henry"]
# 53573729       principal director                \N
# 53573730                       \N                \N
# 53573731                    books                \N
# 53573732                 producer                \N
#
# [53573733 rows x 6 columns]

# %% [markdown]
# ## Filter for leading actors and add column for gender
# Filter for leading actors based on imdb's principals data which contains for each movie the most important people (i. e. actors, actress, directors etc.). The importance is given by imdb and stored in the 'ordering' column

# %%
# filter for actors and actress in principals
principal_actors = principals_raw[(principals_raw["category"] == "actress") | (principals_raw["category"] == "actor")] 

# add gender column (0=male, 1=female)
principal_actors["gender"] = 0
principal_actors.loc[principal_actors["category"] == "actress"] = 1

# select ony important columns of principal and actors data set and join them left
actors = principal_actors[["tconst",	"ordering", "nconst"]].merge(actors_raw[["nconst",	"primaryName",	"birthYear", "deathYear"]], how="left", on="nconst")
print("Number of male actors:", sum(actors["gender"]))
print("Number of actors", actors.size)
actors
# Out:
#        tconst  ordering     nconst category job        characters
# 11  tt0000005         1  nm0443482    actor  \N    ["Blacksmith"]
# 12  tt0000005         2  nm0653042    actor  \N     ["Assistant"]
# 16  tt0000007         1  nm0179163    actor  \N                \N
# 17  tt0000007         2  nm0183947    actor  \N                \N
# 21  tt0000008         1  nm0653028    actor  \N  ["Sneezing Man"]
# C:\Users\sidla\AppData\Local\Temp\ipykernel_26740\1455474259.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   principal_actors["gender"] = 0
#        tconst  ordering     nconst category job        characters  gender
# 11  tt0000005         1  nm0443482    actor  \N    ["Blacksmith"]       0
# 12  tt0000005         2  nm0653042    actor  \N     ["Assistant"]       0
# 16  tt0000007         1  nm0179163    actor  \N                \N       0
# 17  tt0000007         2  nm0183947    actor  \N                \N       0
# 21  tt0000008         1  nm0653028    actor  \N  ["Sneezing Man"]       0
# 146907740
# 209868200
#              tconst  ordering     nconst category job  \
# 0         tt0000005         1  nm0443482    actor  \N
# 1         tt0000005         2  nm0653042    actor  \N
# 2         tt0000007         1  nm0179163    actor  \N
# 3         tt0000007         2  nm0183947    actor  \N
# 4         tt0000008         1  nm0653028    actor  \N
# ...             ...       ...        ...      ...  ..
# 20986815          1         1          1        1   1
# 20986816  tt9916880         1  nm1483166    actor  \N
# 20986817          1         1          1        1   1
# 20986818  tt9916880         3  nm0286175    actor  \N
# 20986819          1         1          1        1   1
#
#                                               characters  gender  \
# 0                                         ["Blacksmith"]       0
# 1                                          ["Assistant"]       0
# 2                                                     \N       0
# 3                                                     \N       0
# 4                                       ["Sneezing Man"]       0
# ...                                                  ...     ...
# 20986815                                               1       1
# 20986816  ["Rude Ralph","Mischievous Mike","Jolly Josh"]       0
# 20986817                                               1       1
# 20986818             ["Dad","Aerobic Al","Nasty Nicola"]       0
# 20986819                                               1       1
#
#                primaryName birthYear deathYear
# 0           Charles Kayser      1878      1966
# 1                 John Ott      1850      1931
# 2         James J. Corbett      1866      1933
# 3           Peter Courtney      1867      1896
# 4                 Fred Ott      1860      1936
# ...                    ...       ...       ...
# 20986815               NaN       NaN       NaN
# 20986816        Aidan Cook        \N        \N
# 20986817               NaN       NaN       NaN
# 20986818    Wayne Forester        \N        \N
# 20986819               NaN       NaN       NaN
#
# [20986820 rows x 10 columns]

# %% [markdown]
# ## Add column for age of actor during start of movie

# %%
# load in movie data and select relevent columns: tconst and startYear
movies = pd.read_csv('data/title.basics.tsv/data.tsv', sep='\t')[["tcont", "startYear"]]

# join movie data with actors

# add age_at_movie_start column

# remove startYear COlumn
